# %% [markdown]
# # **Let's Import Libraries**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random
from scipy import stats
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import mean_squared_error,roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold,StratifiedKFold
from xgboost import XGBRegressor
from sklearn import preprocessing
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/30-days-of-ml/sample_submission.csv
# /kaggle/input/30-days-of-ml/train.csv
# /kaggle/input/30-days-of-ml/test.csv

# %%
train = pd.read_csv('../input/30-days-of-ml/train.csv')
test  = pd.read_csv('../input/30-days-of-ml/test.csv')
submit = pd.read_csv('../input/30-days-of-ml/sample_submission.csv')

# %% [markdown]
# # **Let's Analyse our data**

# %%
train.head()
# Out:
#    id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont5     cont6  \
# 0   1    B    B    B    C    B    B    A    E    C  ...  0.400361  0.160266
# 1   2    B    B    A    A    B    D    A    F    A  ...  0.533087  0.558922
# 2   3    A    A    A    C    B    D    A    D    A  ...  0.650609  0.375348
# 3   4    B    B    A    C    B    D    A    E    C  ...  0.668980  0.239061
# 4   6    A    A    A    C    B    D    A    E    A  ...  0.686964  0.420667
#
#       cont7     cont8     cont9    cont10    cont11    cont12    cont13  \
# 0  0.310921  0.389470  0.267559  0.237281  0.377873  0.322401  0.869850
# 1  0.516294  0.594928  0.341439  0.906013  0.921701  0.261975  0.465083
# 2  0.902567  0.555205  0.843531  0.748809  0.620126  0.541474  0.763846
# 3  0.732948  0.679618  0.574844  0.346010  0.714610  0.540150  0.280682
# 4  0.648182  0.684501  0.956692  1.000773  0.776742  0.625849  0.250823
#
#      target
# 0  8.113634
# 1  8.481233
# 2  8.364351
# 3  8.049253
# 4  7.972260
#
# [5 rows x 26 columns]

# %%
train.tail()
# Out:
#             id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont5  \
# 299995  499993    B    B    A    A    B    D    A    E    A  ...  0.769792
# 299996  499996    A    B    A    C    B    B    A    E    E  ...  0.528056
# 299997  499997    B    B    A    C    B    C    A    E    G  ...  0.688747
# 299998  499998    A    B    A    C    B    B    A    E    E  ...  0.344404
# 299999  499999    A    A    A    C    A    D    A    E    A  ...  0.565347
#
#            cont6     cont7     cont8     cont9    cont10    cont11    cont12  \
# 299995  0.450538  0.934360  1.005077  0.853726  0.422541  1.063463  0.697685
# 299996  0.508502  0.358247  0.257825  0.433525  0.301015  0.268447  0.577055
# 299997  0.372425  0.364936  0.383224  0.551825  0.661007  0.629606  0.714139
# 299998  0.424243  0.382028  0.468819  0.351036  0.288768  0.611169  0.380254
# 299999  0.328669  0.789165  0.960406  0.776019  0.734707  0.484392  0.639754
#
#           cont13    target
# 299995  0.506404  7.945605
# 299996  0.823611  7.326118
# 299997  0.245732  8.706755
# 299998  0.332030  7.229569
# 299999  0.689317  8.631146
#
# [5 rows x 26 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 26 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      300000 non-null  int64
#  1   cat0    300000 non-null  object
#  2   cat1    300000 non-null  object
#  3   cat2    300000 non-null  object
#  4   cat3    300000 non-null  object
#  5   cat4    300000 non-null  object
#  6   cat5    300000 non-null  object
#  7   cat6    300000 non-null  object
#  8   cat7    300000 non-null  object
#  9   cat8    300000 non-null  object
#  10  cat9    300000 non-null  object
#  11  cont0   300000 non-null  float64
#  12  cont1   300000 non-null  float64
#  13  cont2   300000 non-null  float64
#  14  cont3   300000 non-null  float64
#  15  cont4   300000 non-null  float64
#  16  cont5   300000 non-null  float64
#  17  cont6   300000 non-null  float64
#  18  cont7   300000 non-null  float64
#  19  cont8   300000 non-null  float64
#  20  cont9   300000 non-null  float64
#  21  cont10  300000 non-null  float64
#  22  cont11  300000 non-null  float64
#  23  cont12  300000 non-null  float64
#  24  cont13  300000 non-null  float64
#  25  target  300000 non-null  float64
# dtypes: float64(15), int64(1), object(10)
# memory usage: 59.5+ MB

# %%
train.describe()
# Out:
#                   id          cont0          cont1          cont2  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean   250018.576947       0.527335       0.460926       0.490498
# std    144450.150010       0.230599       0.214003       0.253346
# min         1.000000      -0.118039      -0.069309      -0.056104
# 25%    124772.500000       0.405965       0.310494       0.300604
# 50%    250002.500000       0.497053       0.427903       0.502462
# 75%    375226.500000       0.668060       0.615113       0.647512
# max    499999.000000       1.058443       0.887253       1.034704
#
#                cont3          cont4          cont5          cont6  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean        0.496689       0.491654       0.510526       0.467476
# std         0.219199       0.240074       0.228232       0.210331
# min         0.130676       0.255908       0.045915      -0.224689
# 25%         0.329783       0.284188       0.354141       0.342873
# 50%         0.465026       0.390470       0.488865       0.429383
# 75%         0.664451       0.696599       0.669625       0.573383
# max         1.039560       1.055424       1.067649       1.111552
#
#                cont7          cont8          cont9         cont10  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean        0.537119       0.498456       0.474872       0.474492
# std         0.218140       0.239920       0.218007       0.255949
# min         0.203763      -0.260275       0.117896       0.048732
# 25%         0.355825       0.332486       0.306874       0.276017
# 50%         0.504661       0.439151       0.434620       0.459975
# 75%         0.703441       0.606056       0.614333       0.691579
# max         1.032837       1.040229       0.982922       1.055960
#
#               cont11         cont12         cont13         target
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean        0.473216       0.494561       0.508273       8.241979
# std         0.222022       0.247292       0.222950       0.746555
# min         0.052608      -0.074208       0.151050       0.140329
# 25%         0.308151       0.289074       0.300669       7.742071
# 50%         0.433812       0.422887       0.472400       8.191373
# 75%         0.642057       0.714502       0.758447       8.728634
# max         1.071444       0.975035       0.905992      10.411992

# %%
train.isnull().sum()
# Out:
# id        0
# cat0      0
# cat1      0
# cat2      0
# cat3      0
# cat4      0
# cat5      0
# cat6      0
# cat7      0
# cat8      0
# cat9      0
# cont0     0
# cont1     0
# cont2     0
# cont3     0
# cont4     0
# cont5     0
# cont6     0
# cont7     0
# cont8     0
# cont9     0
# cont10    0
# cont11    0
# cont12    0
# cont13    0
# target    0
# dtype: int64

# %%
test.head()
# Out:
#    id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont4     cont5  \
# 0   0    B    B    B    C    B    B    A    E    E  ...  0.476739  0.376350
# 1   5    A    B    A    C    B    C    A    E    C  ...  0.285509  0.860046
# 2  15    B    A    A    A    B    B    A    E    D  ...  0.697272  0.683600
# 3  16    B    B    A    C    B    D    A    E    A  ...  0.719306  0.777890
# 4  17    B    B    A    C    B    C    A    E    C  ...  0.313032  0.431007
#
#       cont6     cont7     cont8     cont9    cont10    cont11    cont12  \
# 0  0.337884  0.321832  0.445212  0.290258  0.244476  0.087914  0.301831
# 1  0.798712  0.835961  0.391657  0.288276  0.549568  0.905097  0.850684
# 2  0.404089  0.879379  0.275549  0.427871  0.491667  0.384315  0.376689
# 3  0.730954  0.644315  1.024017  0.391090  0.988340  0.411828  0.393585
# 4  0.390992  0.408874  0.447887  0.390253  0.648932  0.385935  0.370401
#
#      cont13
# 0  0.845702
# 1  0.693940
# 2  0.508099
# 3  0.461372
# 4  0.900412
#
# [5 rows x 25 columns]

# %%
test.tail()
# Out:
#             id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont4  \
# 199995  499987    B    A    A    C    B    D    A    E    E  ...  0.287454
# 199996  499990    B    A    A    C    B    B    A    E    C  ...  0.794881
# 199997  499991    A    B    B    C    B    B    A    E    C  ...  0.514487
# 199998  499994    A    A    A    C    B    D    A    D    A  ...  0.286144
# 199999  499995    A    A    A    C    B    D    A    E    A  ...  0.286755
#
#            cont5     cont6     cont7     cont8     cont9    cont10    cont11  \
# 199995  0.543800  0.682378  1.028978  1.022741  0.683903  0.877273  0.532410
# 199996  0.432778  0.389775  0.359871  0.550013  0.492082  0.202295  0.416875
# 199997  0.060997  0.171741  0.317185  0.150340  0.122109  0.390524  0.334026
# 199998  1.061710  0.819811  0.901241  0.555339  0.844315  0.894193  0.794102
# 199999  1.065725  0.687682  0.654738  0.574575  0.617467  0.694336  0.745698
#
#           cont12    cont13
# 199995  0.605397  0.884581
# 199996  0.406205  0.758665
# 199997  0.378987  0.839416
# 199998  0.844279  0.890473
# 199999  0.568525  0.783568
#
# [5 rows x 25 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 25 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      200000 non-null  int64
#  1   cat0    200000 non-null  object
#  2   cat1    200000 non-null  object
#  3   cat2    200000 non-null  object
#  4   cat3    200000 non-null  object
#  5   cat4    200000 non-null  object
#  6   cat5    200000 non-null  object
#  7   cat6    200000 non-null  object
#  8   cat7    200000 non-null  object
#  9   cat8    200000 non-null  object
#  10  cat9    200000 non-null  object
#  11  cont0   200000 non-null  float64
#  12  cont1   200000 non-null  float64
#  13  cont2   200000 non-null  float64
#  14  cont3   200000 non-null  float64
#  15  cont4   200000 non-null  float64
#  16  cont5   200000 non-null  float64
#  17  cont6   200000 non-null  float64
#  18  cont7   200000 non-null  float64
#  19  cont8   200000 non-null  float64
#  20  cont9   200000 non-null  float64
#  21  cont10  200000 non-null  float64
#  22  cont11  200000 non-null  float64
#  23  cont12  200000 non-null  float64
#  24  cont13  200000 non-null  float64
# dtypes: float64(14), int64(1), object(10)
# memory usage: 38.1+ MB

# %%
test.describe()
# Out:
#                   id          cont0          cont1          cont2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean   249970.884580       0.526858       0.460882       0.491686
# std    144169.245904       0.230506       0.213896       0.252852
# min         0.000000      -0.117993      -0.069316      -0.056095
# 25%    125316.750000       0.405787       0.310536       0.302189
# 50%    249997.000000       0.496602       0.427656       0.503075
# 75%    374649.750000       0.666389       0.615041       0.648234
# max    499995.000000       1.058434       0.887253       1.034687
#
#                cont3          cont4          cont5          cont6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.496263       0.492200       0.509944       0.468050
# std         0.219304       0.240251       0.228100       0.210167
# min         0.130655       0.255903       0.045921      -0.224613
# 25%         0.328865       0.284188       0.353682       0.342813
# 50%         0.464590       0.395080       0.488378       0.429819
# 75%         0.663401       0.697252       0.668586       0.573861
# max         1.039558       1.055423       1.067641       1.111540
#
#                cont7          cont8          cont9         cont10  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.537617       0.497587       0.474630       0.473625
# std         0.218197       0.239337       0.217558       0.255307
# min         0.203763      -0.260236       0.117894       0.048734
# 25%         0.356482       0.332762       0.306940       0.274991
# 50%         0.505216       0.438716       0.434610       0.460042
# 75%         0.703289       0.605368       0.610768       0.690143
# max         1.032823       1.040208       0.982928       1.055955
#
#               cont11         cont12         cont13
# count  200000.000000  200000.000000  200000.000000
# mean        0.473589       0.492756       0.508303
# std         0.221844       0.247105       0.222977
# min         0.052615      -0.074201       0.151052
# 25%         0.308495       0.288094       0.300697
# 50%         0.433857       0.422065       0.472446
# 75%         0.642201       0.711038       0.758496
# max         1.071445       0.975032       0.906013

# %%
test.isnull().sum()
# Out:
# id        0
# cat0      0
# cat1      0
# cat2      0
# cat3      0
# cat4      0
# cat5      0
# cat6      0
# cat7      0
# cat8      0
# cat9      0
# cont0     0
# cont1     0
# cont2     0
# cont3     0
# cont4     0
# cont5     0
# cont6     0
# cont7     0
# cont8     0
# cont9     0
# cont10    0
# cont11    0
# cont12    0
# cont13    0
# dtype: int64

# %%
categorical_cols=['cat'+str(i) for i in range(10)]
continous_cols=['cont'+str(i) for i in range(14)]

# %%
print(categorical_cols)
print(32*"----") 
print(continous_cols)
# Out:
# ['cat0', 'cat1', 'cat2', 'cat3', 'cat4', 'cat5', 'cat6', 'cat7', 'cat8', 'cat9']
# --------------------------------------------------------------------------------------------------------------------------------
# ['cont0', 'cont1', 'cont2', 'cont3', 'cont4', 'cont5', 'cont6', 'cont7', 'cont8', 'cont9', 'cont10', 'cont11', 'cont12', 'cont13']

# %% [markdown]
# # **Sounds Good,We can proceed**

# %% [markdown]
# # Heat Map

# %%
corr = train[continous_cols+['target']].corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_2fda4_row0_col0,#T_2fda4_row1_col1,#T_2fda4_row2_col2,#T_2fda4_row3_col3,#T_2fda4_row4_col4,#T_2fda4_row5_col5,#T_2fda4_row6_col6,#T_2fda4_row7_col7,#T_2fda4_row8_col8,#T_2fda4_row9_col9,#T_2fda4_row10_col10,#T_2fda4_row11_col11,#T_2fda4_row12_col12,#T_2fda4_row13_col13,#T_2fda4_row14_col14{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_2fda4_row0_col1,#T_2fda4_row5_col14,#T_2fda4_row6_col14,#T_2fda4_row9_col14,#T_2fda4_row12_col1{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_2fda4_row0_col2{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_2fda4_row0_col3,#T_2fda4_row6_col0,#T_2fda4_row6_col8{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_2fda4_row0_col4,#T_2fda4_row5_col2,#T_2fda4_row10_col2{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_2fda4_row0_col5,#T_2fda4_row5_col0,#T_2fda4_row8_col5,#T_2fda4_row9_col0{
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }#T_2fda4_row0_col6{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_2fda4_row0_col7{
#             background-color:  #cfdaea;
#             color:  #000000;
#         }#T_2fda4_row0_col8,#T_2fda4_row0_col9{
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }#T_2fda4_row0_col10,#T_2fda4_row9_col10,#T_2fda4_row10_col0{
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }#T_2fda4_row0_col11,#T_2fda4_row11_col7{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_2fda4_row0_col12{
#             background-color:  #edd2c3;
#             color:  #000000;
#         }#T_2fda4_row0_col13,#T_2fda4_row2_col14,#T_2fda4_row7_col14,#T_2fda4_row11_col14{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_2fda4_row0_col14{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_2fda4_row1_col0,#T_2fda4_row14_col5{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_2fda4_row1_col2,#T_2fda4_row14_col8{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_2fda4_row1_col3,#T_2fda4_row4_col12,#T_2fda4_row13_col6{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_2fda4_row1_col4,#T_2fda4_row4_col10{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_2fda4_row1_col5,#T_2fda4_row1_col7,#T_2fda4_row1_col9,#T_2fda4_row1_col11,#T_2fda4_row13_col2{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_2fda4_row1_col6,#T_2fda4_row3_col2{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_2fda4_row1_col8,#T_2fda4_row1_col10,#T_2fda4_row8_col6{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_2fda4_row1_col12{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_2fda4_row1_col13,#T_2fda4_row11_col4{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_2fda4_row1_col14,#T_2fda4_row4_col13,#T_2fda4_row5_col1,#T_2fda4_row8_col4,#T_2fda4_row9_col4{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_2fda4_row2_col0,#T_2fda4_row2_col3,#T_2fda4_row2_col5,#T_2fda4_row2_col6,#T_2fda4_row2_col7,#T_2fda4_row2_col8,#T_2fda4_row2_col9,#T_2fda4_row2_col10,#T_2fda4_row2_col11,#T_2fda4_row2_col12,#T_2fda4_row2_col13,#T_2fda4_row5_col4,#T_2fda4_row8_col1,#T_2fda4_row12_col2,#T_2fda4_row12_col4,#T_2fda4_row13_col14{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_2fda4_row2_col1,#T_2fda4_row4_col1,#T_2fda4_row6_col1,#T_2fda4_row11_col2{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_2fda4_row2_col4{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_2fda4_row3_col0,#T_2fda4_row6_col5{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_2fda4_row3_col1,#T_2fda4_row8_col2,#T_2fda4_row9_col1,#T_2fda4_row10_col1,#T_2fda4_row10_col4,#T_2fda4_row14_col1{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_2fda4_row3_col4{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_2fda4_row3_col5,#T_2fda4_row3_col8,#T_2fda4_row3_col9,#T_2fda4_row3_col10{
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }#T_2fda4_row3_col6,#T_2fda4_row4_col11{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_2fda4_row3_col7{
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }#T_2fda4_row3_col11{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_2fda4_row3_col12,#T_2fda4_row7_col10{
#             background-color:  #cedaeb;
#             color:  #000000;
#         }#T_2fda4_row3_col13,#T_2fda4_row10_col13{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_2fda4_row3_col14,#T_2fda4_row4_col14,#T_2fda4_row11_col1{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_2fda4_row4_col0,#T_2fda4_row4_col9{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_2fda4_row4_col2{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_2fda4_row4_col3,#T_2fda4_row12_col13{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_2fda4_row4_col5{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_2fda4_row4_col6{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_2fda4_row4_col7{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_2fda4_row4_col8,#T_2fda4_row6_col2{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_2fda4_row5_col3,#T_2fda4_row10_col3{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }#T_2fda4_row5_col6,#T_2fda4_row8_col3{
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }#T_2fda4_row5_col7,#T_2fda4_row5_col11,#T_2fda4_row8_col7{
#             background-color:  #d7dce3;
#             color:  #000000;
#         }#T_2fda4_row5_col8,#T_2fda4_row5_col10,#T_2fda4_row10_col5{
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }#T_2fda4_row5_col9,#T_2fda4_row9_col5{
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }#T_2fda4_row5_col12{
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }#T_2fda4_row5_col13,#T_2fda4_row6_col4,#T_2fda4_row7_col13{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_2fda4_row6_col3,#T_2fda4_row13_col3{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_2fda4_row6_col7{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_2fda4_row6_col9{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_2fda4_row6_col10,#T_2fda4_row12_col3{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_2fda4_row6_col11{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_2fda4_row6_col12{
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }#T_2fda4_row6_col13,#T_2fda4_row11_col13{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_2fda4_row7_col0,#T_2fda4_row7_col11,#T_2fda4_row11_col10{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_2fda4_row7_col1,#T_2fda4_row9_col2{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_2fda4_row7_col2,#T_2fda4_row7_col4{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_2fda4_row7

# %% [markdown]
# # Data Encoding

# %%
train.drop("id", axis=1, inplace=True)
test.drop("id", axis=1, inplace=True)

# %%
x = train.drop(['target'], axis=1)
y = train['target']
X_test = test.copy()

# %%
ordinal_encoder = OrdinalEncoder()
x[categorical_cols] = ordinal_encoder.fit_transform(x[categorical_cols])
X_test[categorical_cols] = ordinal_encoder.transform(X_test[categorical_cols])
x.head()
# Out:
#    cat0  cat1  cat2  cat3  cat4  cat5  cat6  cat7  cat8  cat9  ...     cont4  \
# 0   1.0   1.0   1.0   2.0   1.0   1.0   0.0   4.0   2.0  13.0  ...  0.610706
# 1   1.0   1.0   0.0   0.0   1.0   3.0   0.0   5.0   0.0  14.0  ...  0.276853
# 2   0.0   0.0   0.0   2.0   1.0   3.0   0.0   3.0   0.0   5.0  ...  0.285074
# 3   1.0   1.0   0.0   2.0   1.0   3.0   0.0   4.0   2.0  10.0  ...  0.284667
# 4   0.0   0.0   0.0   2.0   1.0   3.0   0.0   4.0   0.0  13.0  ...  0.287595
#
#       cont5     cont6     cont7     cont8     cont9    cont10    cont11  \
# 0  0.400361  0.160266  0.310921  0.389470  0.267559  0.237281  0.377873
# 1  0.533087  0.558922  0.516294  0.594928  0.341439  0.906013  0.921701
# 2  0.650609  0.375348  0.902567  0.555205  0.843531  0.748809  0.620126
# 3  0.668980  0.239061  0.732948  0.679618  0.574844  0.346010  0.714610
# 4  0.686964  0.420667  0.648182  0.684501  0.956692  1.000773  0.776742
#
#      cont12    cont13
# 0  0.322401  0.869850
# 1  0.261975  0.465083
# 2  0.541474  0.763846
# 3  0.540150  0.280682
# 4  0.625849  0.250823
#
# [5 rows x 24 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(x, y,test_size=0.2, random_state=50)

# %% [markdown]
# # Application of Xgboost

# %%
xgb_params = {'objective': 'reg:squarederror',
              'n_estimators': 10000,
              'learning_rate': 0.036,
              'subsample': 0.926,
              'colsample_bytree': 0.118,
              'grow_policy':'lossguide',
              'max_depth': 3,
              'booster': 'gbtree', 
              'reg_lambda': 45.1,
              'reg_alpha': 34.9,
              'random_state': 42,
              'reg_lambda': 0.00087,
              'reg_alpha': 23.132}

model_XGB = XGBRegressor(**xgb_params)
model_XGB.fit(X_train, y_train) 
pred_XGB = model_XGB.predict(X_valid)
print(mean_squared_error(y_valid, pred_XGB, squared=False))
# Out:
# 0.7205191769003078

# %% [markdown]
# # Let's Sumit our prediction

# %%
pred = model_XGB.predict(X_test)
# Save the predictions to a CSV file
submit['target']=pred
submit.to_csv('submission.csv', index=False)
